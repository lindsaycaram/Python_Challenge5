# %% [markdown]
# # Studying the Gender Gap
# ### Exploring Recent Graduates

# %% [markdown]
# Data source: The Deparment of Education Statistics
#
# Data includes the yearly percentage of female graduate from 1970 - 2012 for various major categories at the University of Pennsylvania.
#
# Columns and descriptions:
# *  Year	- format YYYY
# *  Agriculture	Architecture
# *  Art and Performance
# *  Biology
# *  Business
# *  Communications and Journalism
# *  Computer Science
# *  Education
# *  Engineering
# *  English
# *  Foreign Languages
# *  Health Professions
# *  Math and Statistics
# *  Physical Sciences
# *  Psychology
# *  Public Administration
# *  Social Sciences and History

# %%
#plots the gender gap of different STEM degrees
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# Observation: In exploring the gender gap within STEM degrees, it appears that the gender gap with males as the majority graduates is present within Engineering and Computer Science. In contrast, there are a majority female graduates within Psychology. The gender gap is closing for Biology, Physical Sciences, and Math & Statistics degrees where the percentage of women is nearly 50%.

# %%
#now include all degree categories in exploring the gender gap
fig2=plt.figure(figsize=(12,18))
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats=["Foreign Languages", "English", "Communications and Journalism", "Art and Performance", "Social Sciences and History"]
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture', 'Business', 'Architecture']

#plot stem degrees
#create sublplots with data and formatting specs
for sp in range(0,18,3):
    ax = fig2.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[int(sp/3)]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[int(sp/3)]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.set_title(stem_cats[int(sp/3)])
    ax.tick_params(bottom="off", top="off", left="off", right="off",labelbottom="off")
        
    if int(sp/3) == 0:
        ax.text(2002, 87, 'Women')
        ax.text(2002, 8, 'Men')
    elif int(sp/3) == 5:
        ax.text(2002, 85, 'Men')
        ax.text(2002, 10, 'Women')
        ax.tick_params(labelbottom="on")

#plot liberal arts degrees
for sp in range(1,19,3):
    
    #since we only have 5 plots, we don't need to iterate for a 6th plot
    if int((sp-1)/3)==5:
        break
    
    #create sublplots with data and formatting specs
    ax = fig2.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[int((sp-1)/3)]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[int((sp-1)/3)]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.set_title(lib_arts_cats[int((sp-1)/3)])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
       
    if int((sp-1)/3) == 0:
        ax.text(2002, 80, 'Women')
        ax.text(2002, 20, 'Men')
   
    if int((sp-1)/3)==4:
        ax.tick_params(labelbottom="on")
    
    continue  
    
#plot other category degrees
#create sublplots with data and formatting specs
for sp in range(2,20,3):
    ax = fig2.add_subplot(6,3,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[int((sp-2)/3)]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[int((sp-2)/3)]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.set_title(other_cats[int((sp-2)/3)])
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom="off")
        
    if int((sp-2)/3) == 0:
        ax.text(2002, 90, 'Women')
        ax.text(2002, 5, 'Men')
    elif int((sp-2)/3) == 5:
        ax.text(2002, 30, 'Women')
        ax.text(2002, 65, 'Men')
        ax.tick_params(labelbottom="on")

plt.savefig("gender_degrees.png")        
plt.show()

# %% [markdown]
# Observation: In comparing STEM, Liberal Arts, and Other Categories, the gedner gap where the percentage of male graduats is the majority is only evident within the STEM category. Both Liberal Arts and Other Categories have a few majors where females have consistenly b
